# %%
import pandas as pd
import re
from rdkit import Chem
from rdkit.Chem import Descriptors

# %%
df = pd.read_csv('data_filter.csv', encoding='utf-8-sig')
print(df.head(898))
# Out:
#           ID                  NAME  \
# 0    10001.0  2-mercaptopyrimidine
# 1    10002.0  2-mercaptopyrimidine
# 2    10003.0  2-mercaptopyrimidine
# 3    10004.0  2-mercaptopyrimidine
# 4    10005.0  2-mercaptopyrimidine
# ..       ...                   ...
# 893  10911.0   Monoethylene glycol
# 894  10912.0   Monoethylene glycol
# 895  10913.0         Thiourea (TU)
# 896  10914.0         berberine（BB）
# 897  10915.0         berberine（BB）
#
#                                                 SMILES  NaClg/L  Temp  \
# 0                                        S=c1nccc[nH]1     10.0  313K
# 1                                        S=c1nccc[nH]1     50.0  313K
# 2                                        S=c1nccc[nH]1    100.0  313K
# 3                                        S=c1nccc[nH]1    150.0  313K
# 4                                        S=c1nccc[nH]1    200.0  313K
# ..                                                 ...      ...   ...
# 893  C=C(c1ccccc1)C5(c2ccccc2)/C(c3ccccc3)=C(c4cccc...    100.0  323K
# 894  C=C(c1ccccc1)C5(c2ccccc2)/C(c3ccccc3)=C(c4cccc...    100.0  323K
# 895                                            NC(N)=S     30.0  333K
# 896                COc5ccc4CC3c2cc1OCOc1cc2CCN3Cc4c5OC     30.0  333K
# 897                COc5ccc4CC3c2cc1OCOc1cc2CCN3Cc4c5OC     30.0  333K
#
#     Concentration      IE
# 0           20ppm  91.24%
# 1           20ppm  85.56%
# 2           20ppm  83.31%
# 3           20ppm  81.73%
# 4           20ppm  76.29%
# ..            ...     ...
# 893        70wt.%  56.30%
# 894        90wt.%  82.00%
# 895        10mg/L  79.80%
# 896        10mg/L   1.80%
# 897        50mg/L   7.20%
#
# [898 rows x 7 columns]

# %%
for i,item in zip(df['ID'],df['Concentration']):
    item = item.replace(' ','').replace('\n','')
    item = item.replace('×', '*').replace('μ', 'mu').replace('wt.%', 'wt%').replace('ppm','PPM').replace('／','/')
    item = item.replace('?*?','*').replace('*?','*').replace('?5?','-5')
    #item = item.replace('ï¼','/').replace('dm?3', '/l').replace('moll?1','mol/l').replace('L?1','/l').replace('l?1','/l').replace('Â·L-1','/l')
    item = item.replace('?','-')
    item = item.replace('moldm-3','M').replace('moll-1','M').replace('mgL-1','mg/L').replace('mol·L-1','M').replace('mg-L-1','mg/L')
    item = item.replace('Mol/L','M').replace('M/L','M').replace('MOL/L','M').replace('mol/L','M').replace('mol/l','M').replace('mol/m3','mM')
    print(item)
# Out:
# 20PPM
# 20PPM
# 20PPM
# 20PPM
# 20PPM
# 100PPM
# 7*10-5M
# 15*10-5M
# 35*10-5M
# 70*10-5M
# 7*10-5M
# 15*10-5M
# 35*10-5M
# 70*10-5M
# 1*10-5M
# 2.5*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 1*10-5M
# 2.5*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 1*10-5M
# 2.5*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 1*10-5M
# 2.5*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 5PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 150PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 150PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 150PPM
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 150PPM
# 200PPM
# 2*10-4M
# 2*10-4M
# 2*10-4M
# 60PPM
# 60PPM
# 50PPM
# 100PPM
# 200PPM
# 400PPM
# 50PPM
# 100PPM
# 200PPM
# 400PPM
# 1PPM
# 2.5PPM
# 5PPM
# 7.5PPM
# 10PPM
# 1PPM
# 2.5PPM
# 5PPM
# 7.5PPM
# 10PPM
# 0.1mM
# 0.2mM
# 0.4mM
# 0.8mM
# 0.1mM
# 0.2mM
# 0.4mM
# 0.8mM
# 0.0125wt%
# 0.025wt%
# 0.05wt%
# 0.075wt%
# 0.1wt%
# 5PPM
# 10PPM
# 50PPM
# 5PPM
# 10PPM
# 50PPM
# 1mM
# 3mM
# 1mM
# 3mM
# 1*10-6M
# 5*10-6M
# 1*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 1*10-6M
# 5*10-6M
# 1*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 1*10-6M
# 5*10-6M
# 1*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 100mg/L
# 200mg/L
# 400mg/L
# 700mg/L
# 1000mg/L
# 100mg/L
# 200mg/L
# 400mg/L
# 700mg/L
# 1000mg/L
# 50mg/L
# 100mg/L
# 300mg/L
# 500mg/L
# 100PPM
# 250PPM
# 500PPM
# 1000PPM
# 100PPM
# 250PPM
# 500PPM
# 1000PPM
# 100PPM
# 250PPM
# 500PPM
# 1000PPM
# 50mg/L
# 50mg/L
# 1mg/L
# 2.5mg/L
# 5mg/L
# 7.5mg/L
# 10mg/L
# 1mg/L
# 2.5mg/L
# 5mg/L
# 7.5mg/L
# 10mg/L
# 0.01mM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 25PPM
# 33PPM
# 50PPM
# 66PPM
# 75PPM
# 100PPM
# 25PPM
# 33PPM
# 50PPM
# 66PPM
# 75PPM
# 100PPM
# 50mg/L
# 100mg/L
# 300mg/L
# 500mg/L
# 50mg/L
# 100mg/L
# 300mg/L
# 500mg/L
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 25PPM
# 50PPM
# 100PPM
# 25PPM
# 50PPM
# 100PPM
# 0.2mM
# 0.2mM
# 200PPM
# 200PPM
# 200PPM
# 200PPM
# 200PPM
# 200PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 150PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 150PPM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 50PPM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 5PPM
# 10PPM
# 40PPM
# 70PPM
# 100PPM
# 5PPM
# 10PPM
# 40PPM
# 70PPM
# 100PPM
# 50PPM
# 100PPM
# 200PPM
# 400PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 20muM
# 50muM
# 80muM
# 100muM
# 20muM
# 50muM
# 80muM
# 100muM
# 20muM
# 50muM
# 80muM
# 100muM
# 20muM
# 50muM
# 80muM
# 100muM
# 5PPM
# 10PPM
# 20PPM
# 40PPM
# 100PPM
# 0.01mM
# 0.025mM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.01mM
# 0.025mM
# 0.05mM
# 0.1mM
# 0.2mM
# 50PPM
# 100PPM
# 150PPM
# 200PPM
# 250PPM
# 50PPM
# 100PPM
# 150PPM
# 200PPM
# 250PPM
# 0.01mM
# 0.025mM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.01mM
# 0.025mM
# 0.05mM
# 0.1mM
# 0.2mM
# 50PPM
# 50PPM
# 10PPM
# 25PPM
# 50PPM
# 10PPM
# 25PPM
# 50PPM
# 1PPM
# 5PPM
# 10PPM
# 50PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 500PPM
# 50PPM
# 100PPM
# 150PPM
# 200PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 150PPM
# 300PPM
# 450PPM
# 600PPM
# 900PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 0.005mM
# 0.01mM
# 0.02mM
# 0.05mM
# 0.1mM
# 0.005mM
# 0.01mM
# 0.02mM
# 0.05mM
# 0.1mM
# 0.005mM
# 0.01mM
# 0.02mM
# 0.05mM
# 0.1mM
# 1.28mM
# 2.56mM
# 0.035mM
# 0.07mM
# 0.14mM
# 0.1mM
# 100mg/L
# 200mg/L
# 300mg/L
# 400mg/L
# 100mg/L
# 200mg/L
# 300mg/L
# 400mg/L
# 20PPM
# 20PPM
# 20PPM
# 20PPM
# 20PPM
# 5*10-6M
# 1*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 1*10-3M
# 5*10-6M
# 1*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 1*10-3M
# 5*10-6M
# 1*10-5M
# 5*10-5M
# 1*10-4M
# 5*10-4M
# 1*10-3M
# 25*10-6M
# 50*10-6M
# 75*10-6M
# 100*10-6M
# 25*10-6M
# 50*10-6M
# 75*10-6M
# 100*10-6M
# 25*10-6M
# 50*10-6M
# 75*10-6M
# 100*10-6M
# 25*10-6M
# 50*10-6M
# 75*10-6M
# 100*10-6M
# 0.005mM
# 0.01mM
# 0.02mM
# 0.05mM
# 0.1mM
# 0.2mM
# 0.4mM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 150PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 150PPM
# 30PPM
# 60PPM
# 90PPM
# 120PPM
# 150PPM
# 0.5PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 0.5PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 0.5PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 0.5PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 0.5PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 0.5PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 50PPM
# 100PPM
# 200PPM
# 400PPM
# 700PPM
# 1000PPM
# 50PPM
# 100PPM
# 200PPM
# 400PPM
# 700PPM
# 1000PPM
# 50PPM
# 50PPM
# 5PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 0.001mM
# 0.0025mM
# 0.005mM
# 0.01mM
# 0.025mM
# 0.05mM
# 0.001mM
# 0.0025mM
# 0.005mM
# 0.01mM
# 0.025mM
# 0.05mM
# 0.45mM
# 0.91mM
# 1.36mM
# 2.27mM
# 20PPM
# 40PPM
# 80PPM
# 0.2mM
# 0.025mM
# 500PPM
# 500PPM
# 500PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 50PPM
# 100PPM
# 200PPM
# 300PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 5PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 30PPM
# 50PPM
# 80PPM
# 100PPM
# 30PPM
# 50PPM
# 80PPM
# 100PPM
# 20PPM
# 20PPM
# 20PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 25PPM
# 50PPM
# 100PPM
# 5PPM
# 10PPM
# 20PPM
# 40PPM
# 80PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 500PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 500PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 500PPM
# 5PPM
# 10PPM
# 20PPM
# 40PPM
# 80PPM
# 400PPM
# 400PPM
# 25PPM
# 25PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 200PPM
# 300PPM
# 400PPM
# 100PPM
# 100PPM
# 30mg/L
# 30mg/L
# 400mg/L
# 400mg/L
# 400mg/L
# 500PPM
# 10PPM
# 5PPM
# 5PPM
# 0.4878*10-5M
# 1.2195*10-5M
# 2.4390*10-5M
# 4.8780*10-5M
# 0.4878*10-5M
# 1.2195*10-5M
# 2.4390*10-5M
# 4.8780*10-5M
# 0.4878*10-5M
# 1.2195*10-5M
# 2.4390*10-5M
# 4.8780*10-5M
# 0.4878*10-5M
# 1.2195*10-5M
# 2.4390*10-5M
# 4.8780*10-5M
# 100mg/L
# 100mg/L
# 100mg/L
# 100mg/L
# 40mg/L
# 80mg/L
# 50mg/L
# 100mg/L
# 200mg/L
# 400mg/L
# 50mg/L
# 100mg/L
# 200mg/L
# 400mg/L
# 50PPM
# 100PPM
# 150PPM
# 200PPM
# 300PPM
# 400PPM
# 50PPM
# 100PPM
# 150PPM
# 200PPM
# 300PPM
# 400PPM
# 50PPM
# 100PPM
# 150PPM
# 200PPM
# 300PPM
# 400PPM
# 10PPM
# 20PPM
# 30PPM
# 60PPM
# 80PPM
# 0.01M
# 0.01M
# 0.01M
# 0.01M
# 20mg/L
# 40mg/L
# 60mg/L
# 80mg/L
# 20mg/L
# 40mg/L
# 60mg/L
# 80mg/L
# 20mg/L
# 50mg/L
# 100mg/L
# 5mg/L
# 10mg/L
# 20mg/L
# 50mg/L
# 100mg/L
# 5PPM
# 10PPM
# 20PPM
# 40PPM
# 60PPM
# 25PPM
# 50PPM
# 100PPM
# 200PPM
# 20PPM
# 50PPM
# 100PPM
# 20PPM
# 50PPM
# 100PPM
# 20PPM
# 50PPM
# 100PPM
# 20PPM
# 50PPM
# 100PPM
# 3.2*10-5M
# 10-4M
# 3.2*10-4M
# 10-3M
# 3.2*10-3M
# 3.2*10-5M
# 10-4M
# 3.2*10-4M
# 10-3M
# 3.2*10-3M
# 50mg/L
# 100mg/L
# 150mg/L
# 200mg/L
# 250mg/L
# 300PPM
# 400PPM
# 500PPM
# 50mg/L
# 100mg/L
# 200mg/L
# 400mg/L
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 0.0141M
# 0.0212M
# 0.0282M
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 50PPM
# 100PPM
# 200PPM
# 400PPM
# 0.4878*10-5M
# 1.2195*10-5M
# 1.9512*10-5M
# 2.4390*10-5M
# 4.8780*10-5M
# 50PPM
# 100PPM
# 200PPM
# 50PPM
# 100PPM
# 200PPM
# 50PPM
# 100PPM
# 200PPM
# 50PPM
# 100PPM
# 200PPM
# 25mg/L
# 50mg/L
# 100mg/L
# 200mg/L
# 300mg/L
# 400mg/L
# 100mg/L
# 100mg/L
# 100mg/L
# 100mg/L
# 10mg/L
# 20mg/L
# 30mg/L
# 40mg/L
# 50mg/L
# 60mg/L
# 70mg/L
# 300mg/L
# 30wt%
# 50wt%
# 70wt%
# 90wt%
# 50wt%
# 90wt%
# 70wt%
# 90wt%
# 10mg/L
# 10mg/L
# 50mg/L
# 100mg/L
# 5mL/L
# 5mL/L
# 5mL/L
# 5mL/L
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 125PPM
# 150PPM
# 100mg/L
# 50mg/L
# 25PPM
# 25PPM
# 25PPM
# 50mg/L
# 100mg/L
# 200mg/L
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 1PPM
# 2PPM
# 3PPM
# 5PPM
# 10PPM
# 20PPM
# 1PPM
# 5PPM
# 10PPM
# 20PPM
# 50PPM
# 100PPM
# 1PPM
# 2PPM
# 3PPM
# 5PPM
# 10PPM
# 20PPM
# 5mL/L
# 5mL/L
# 5mL/L
# 5mL/L
# 250PPM
# 500PPM
# 1000PPM
# 200PPM
# 200PPM
# 200PPM
# 100PPM
# 100PPM
# 0.1PPM
# 0.5PPM
# 1PPM
# 5PPM
# 10PPM
# 15PPM
# 0.1PPM
# 0.5PPM
# 1PPM
# 5PPM
# 10PPM
# 15PPM
# 20PPM
# 100mg/L
# 150mg/L
# 0.63mM
# 30wt%
# 70PPM
# 70PPM
# 5mg/L
# 10mg/L
# 25mg/L
# 5mg/L
# 10mg/L
# 25mg/L
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 0.12mM
# 0.6mM
# 2.41mM
# 20mg/L
# 50mg/L
# 100mg/L
# 150mg/L
# 500mg/L
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 4mg/L
# 4mg/L
# 10PPM
# 25PPM
# 10PPM
# 200PPM
# 100PPM
# 100PPM
# 100PPM
# 0.15wt%
# 0.15wt%
# 100mg/L
# 100mg/L
# 100mg/L
# 400PPM
# 50mg/L
# 50mg/L
# 50mg/L
# 50mg/L
# 1.4muM
# 1.4muM
# 1.4muM
# 2.7muM
# 2.7muM
# 2.7muM
# 8.2muM
# 8.2muM
# 8.2muM
# 13.6muM
# 13.6muM
# 13.6muM
# 27.2muM
# 27.2muM
# 27.2muM
# 54.4muM
# 54.4muM
# 54.4muM
# 3mM
# 1.61*10-5M
# 3.32*10-5M
# 8.1*10-5M
# 1.61*10-4M
# 3.32*10-4M
# 50PPM
# 100PPM
# 200PPM
# 50PPM
# 100PPM
# 200PPM
# 50PPM
# 100PPM
# 200PPM
# 50PPM
# 100PPM
# 200PPM
# 50PPM
# 100PPM
# 200PPM
# 50PPM
# 100PPM
# 200PPM
# 1mg/L
# 0.75mg/L
# 1mg/L
# 0.75mg/L
# 1mg/L
# 0.75mg/L
# 1mg/L
# 0.75mg/L
# 1mg/L
# 0.75mg/L
# 100mg/L
# 100mg/L
# 100mg/L
# 5PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 0.1*103M
# 0.4*103M
# 1.0*103M
# 2.0*103M
# 4.0*103M
# 5PPM
# 10PPM
# 15PPM
# 20PPM
# 5PPM
# 10PPM
# 15PPM
# 20PPM
# 20mg/L
# 40mg/L
# 60mg/L
# 80mg/L
# 100mg/L
# 200mg/L
# 80mg/L
# 80mg/L
# 80mg/L
# 80mg/L
# 80mg/L
# 100mg/L
# 100mg/L
# 100mg/L
# 100mg/L
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 100mg/L
# 100mg/L
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 20mg/L
# 40mg/L
# 80mg/L
# 100mg/L
# 80mg/L
# 80mg/L
# 80mg/L
# 5mg/L
# 10mg/L
# 15mg/L
# 20mg/L
# 25mg/L
# 5mg/L
# 10mg/L
# 15mg/L
# 20mg/L
# 25mg/L
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 0.65mM
# 0.43mM
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 0.1mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 1mg/L
# 0.5mg/L
# 0.2mg/L
# 0.1mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.2mg/L
# 0.1mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 0.1mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 1mg/L
# 0.5mg/L
# 0.2mg/L
# 0.1mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.2mg/L
# 0.1mg/L
# 25mg/L
# 10mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.2mg/L
# 0.1mg/L
# 25mg/L
# 10mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.2mg/L
# 0.1mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.2mg/L
# 0.1mg/L
# 0.05mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.2mg/L
# 0.1mg/L
# 0.05mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 0.1mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 0.1mg/L
# 25mg/L
# 2.5mg/L
# 0.25mg/L
# 5mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 0.1mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 0.1mg/L
# 25mg/L
# 2.5mg/L
# 0.25mg/L
# 5mg/L
# 2.5mg/L
# 1mg/L
# 0.5mg/L
# 0.25mg/L
# 20PPM
# 20PPM
# 20PPM
# 5mg/L
# 10mg/L
# 15mg/L
# 20mg/L
# 25mg/L
# 5mg/L
# 10mg/L
# 15mg/L
# 20mg/L
# 25mg/L
# 5mg/L
# 10mg/L
# 15mg/L
# 20mg/L
# 25mg/L
# 5mg/L
# 10mg/L
# 15mg/L
# 20mg/L
# 25mg/L
# 10PPM
# 50PPM
# 100PPM
# 200PPM
# 50PPM
# 50PPM
# 50PPM
# 10PPM
# 20PPM
# 30PPM
# 20PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 30PPM
# 20PPM
# 20PPM
# 20PPM
# 4PPM
# 80PPM
# 120PPM
# 10PPM
# 40PPM
# 80PPM
# 20PPM
# 20PPM
# 20PPM
# 20PPM
# 20PPM
# 20PPM
# 25mg/L
# 50mg/L
# 100mg/L
# 150mg/L
# 200mg/L
# 250mg/L
# 300mg/L
# 25mg/L
# 75mg/L
# 100mg/L
# 125mg/L
# 5mg/L
# 10mg/L
# 30mg/L
# 50mg/L
# 100mg/L
# 5mg/L
# 10mg/L
# 20mg/L
# 30mg/L
# 50mg/L
# 100mg/L
# 5mg/L
# 10mg/L
# 30mg/L
# 50mg/L
# 100mg/L
# 5mg/L
# 10mg/L
# 30mg/L
# 50mg/L
# 100mg/L
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 1*10-3M
# 5*10-3M
# 1*10-2M
# 1.5*10-2M
# 2*10-2M
# 100PPM
# 250PPM
# 500PPM
# 1000PPM
# 5PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 5PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 1PPM
# 5PPM
# 10PPM
# 50PPM
# 10PPM
# 10PPM
# 10PPM
# 10PPM
# 100PPM
# 400PPM
# 700PPM
# 1000PPM
# 100PPM
# 400PPM
# 700PPM
# 1000PPM
# 0.488*10-5M
# 1.22*10-5M
# 2.44*10-5M
# 4.88*10-5M
# 0.488*10-5M
# 1.22*10-5M
# 2.44*10-5M
# 4.88*10-5M
# 0.4878*10-5M
# 1.2195*10-5M
# 2.4390*10-5M
# 4.878*10-5M
# 0.4878*10-5M
# 1.2195*10-5M
# 2.4390*10-5M
# 4.878*10-5M
# 0.4878*10-5M
# 1.2195*10-5M
# 2.4390*10-5M
# 4.878*10-5M
# 0.4878*10-5M
# 1.2195*10-5M
# 2.4390*10-5M
# 4.878*10-5M
# 10PPM
# 10PPM
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 100PPM
# 7.68mM
# 400PPM
# 400PPM
# 400PPM
# 50mg/L
# 75mg/L
# 100mg/L
# 125mg/L
# 150mg/L
# 175mg/L
# 200mg/L
# 150mg/L
# 150mg/L
# 150mg/L
# 150mg/L
# 150mg/L
# 150mg/L
# 150mg/L
# 150mg/L
# 150mg/L
# 150mg/L
# 150mg/L
# 2PPM
# 3PPM
# 5PPM
# 7PPM
# 9PPM
# 2PPM
# 3PPM
# 5PPM
# 7PPM
# 1PPM
# 3PPM
# 5PPM
# 78PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 150PPM
# 10PPM
# 25PPM
# 50PPM
# 100PPM
# 150PPM
# 250mg/L
# 500mg/L
# 1000mg/L
# 200mg/L
# 300mg/L
# 400mg/L
# 500mg/L
# 50PPM
# 70PPM
# 100PPM
# 200PPM
# 500PPM
# 0.07*10-5mM
# 0.14*10-5mM
# 0.27*10-5mM
# 0.82*10-5mM
# 1.36*10-5mM
# 2.72*10-5mM
# 4.08*10-5mM
# 5.44*10-5mM
# 10mg/L
# 10PPM
# 1.5PPM
# 2.5PPM
# 5PPM
# 10PPM
# 25PPM
# 100PPM
# 200PPM
# 10PPM
# 0.5PPM
# 1PPM
# 1.5PPM
# 2.5PPM
# 5PPM
# 10PPM
# 25PPM
# 100PPM
# 200PPM
# 10PPM
# 0.5PPM
# 1PPM
# 1.5PPM
# 2.5PPM
# 5PPM
# 10PPM
# 15PPM
# 25PPM
# 50PPM
# 100PPM
# 200PPM
# 50mg/L
# 100mg/L
# 200mg/L
# 400mg/L
# 50mg/L
# 100mg/L
# 200mg/L
# 400mg/L
# 50PPM
# 100PPM
# 200PPM
# 400PPM
# 0.17mM
# 0.34mM
# 0.17mM
# 0.34mM
# 0.17mM
# 0.34mM
# 0.17mM
# 0.34mM
# 0.34mM
# 0.34mM
# 0.34mM
# 2.56mM
# 7.68mM
# 2.56mM
# 7.68mM
# 2.56mM
# 7.68mM
# 2.56mM
# 7.68mM
# 1.28mM
# 2.56mM
# 1.28mM
# 2.56mM
# 1.28mM
# 2.56mM
# 1.28mM
# 2.56mM
# 0.035mM
# 0.070mM
# 0.140mM
# 100mg/L
# 200mg/L
# 300mg/L
# 400mg/L
# 500mg/L
# 0.1g/L
# 0.2g/L
# 0.3g/L
# 0.4g/L
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 10PPM
# 25PPM
# 50PPM
# 75PPM
# 100PPM
# 400PPM
# 400PPM
# 30mg/L
# 50mg/L
# 80mg/L
# 100mg/L
# 30mg/L
# 50mg/L
# 80mg/L
# 100mg/L
# 0.12mM
# 0.60mM
# 2.41mM
# 25PPM
# 25PPM
# 50PPM
# 75PPM
# 25PPM
# 20mg/L
# 40mg/L
# 80mg/L
# 100mg/L
# 80mg/L
# 80mg/L
# 80mg/L

# %%
df['Concentration'] = df['Concentration'].str.replace(' ','').str.replace('\n','')
df['Concentration'] = df['Concentration'].str.replace('×', '*').str.replace('μ', 'mu').str.replace('wt.%', 'wt%').str.replace('ppm','PPM').str.replace('／','/')
df['Concentration'] = df['Concentration'].str.replace('?*?','*').str.replace('*?','*').str.replace('?5?','-5')
df['Concentration'] = df['Concentration'].str.replace('?','-')
df['Concentration'] = df['Concentration'].str.replace('moldm-3','M').str.replace('moll-1','M').str.replace('mgL-1','mg/L').str.replace('mol·L-1','M').str.replace('mg-L-1','mg/L')
df['Concentration'] = df['Concentration'].str.replace('Mol/L','M').str.replace('M/L','M').str.replace('MOL/L','M').str.replace('mol/L','M').str.replace('mol/l','M').str.replace('mol/m3','mM')
df['TempK'] = df['Temp'].str.replace('room temperature', '298').str.replace('±1','').str.replace(' ','').str.replace('K','').str.replace('k','')
df['IE'] = df['IE'].str.rstrip('%').astype('float') / 100
df.head(898)
# Out:
#           ID                  NAME  \
# 0    10001.0  2-mercaptopyrimidine
# 1    10002.0  2-mercaptopyrimidine
# 2    10003.0  2-mercaptopyrimidine
# 3    10004.0  2-mercaptopyrimidine
# 4    10005.0  2-mercaptopyrimidine
# ..       ...                   ...
# 893  10911.0   Monoethylene glycol
# 894  10912.0   Monoethylene glycol
# 895  10913.0         Thiourea (TU)
# 896  10914.0         berberine（BB）
# 897  10915.0         berberine（BB）
#
#                                                 SMILES  NaClg/L  Temp  \
# 0                                        S=c1nccc[nH]1     10.0  313K
# 1                                        S=c1nccc[nH]1     50.0  313K
# 2                                        S=c1nccc[nH]1    100.0  313K
# 3                                        S=c1nccc[nH]1    150.0  313K
# 4                                        S=c1nccc[nH]1    200.0  313K
# ..                                                 ...      ...   ...
# 893  C=C(c1ccccc1)C5(c2ccccc2)/C(c3ccccc3)=C(c4cccc...    100.0  323K
# 894  C=C(c1ccccc1)C5(c2ccccc2)/C(c3ccccc3)=C(c4cccc...    100.0  323K
# 895                                            NC(N)=S     30.0  333K
# 896                COc5ccc4CC3c2cc1OCOc1cc2CCN3Cc4c5OC     30.0  333K
# 897                COc5ccc4CC3c2cc1OCOc1cc2CCN3Cc4c5OC     30.0  333K
#
#     Concentration      IE TempK
# 0           20PPM  0.9124   313
# 1           20PPM  0.8556   313
# 2           20PPM  0.8331   313
# 3           20PPM  0.8173   313
# 4           20PPM  0.7629   313
# ..            ...     ...   ...
# 893         70wt%  0.5630   323
# 894         90wt%  0.8200   323
# 895        10mg/L  0.7980   333
# 896        10mg/L  0.0180   333
# 897        50mg/L  0.0720   333
#
# [898 rows x 8 columns]

# %%
def fix_scientific_notation(concentration_str):
    # 使用正则表达式匹配科学计数法的模式：数字 * 10 ± 指数 单位
    pattern1 = r"([0-9.]+)\*10([-+]?[0-9]+)([a-zA-Z]+)?"
    pattern2 = r"10(-[0-9]+)([a-zA-Z]+)?"
    match1 = re.match(pattern1, concentration_str.strip())
    match2 = re.match(pattern2, concentration_str.strip())
    if match1:
        number, exponent, unit = match1.groups()
        # 将其转换为标准的科学计数法形式
        if number is None:
            number = 1
        decimal_value = float(number) * (10 ** int(exponent))
        decimal_value = f"{decimal_value:.10f}"
        fixed_notation = f"{decimal_value}{unit or ''}".strip()
        return fixed_notation
    elif match2:
        exponent, unit = match2.groups()
        decimal_value = (10 ** int(exponent))
        decimal_value = f"{decimal_value:.10f}"
        fixed_notation = f"{decimal_value}{unit or ''}".strip()
        print(match2, decimal_value)
        return fixed_notation
    else:
        # 如果不是科学计数法，则返回原字符串
        return concentration_str

# %%
# 假设你已经读取了CSV文件到df DataFrame中
# df = pd.read_csv('solution_properties.csv', encoding='utf-8')

# 应用函数到'Concentration'列
df['Fixed_Concentration'] = df['Concentration'].apply(fix_scientific_notation)
df.head(898)
# Out:
# <re.Match object; span=(0, 5), match='10-4M'> 0.0001000000
# <re.Match object; span=(0, 5), match='10-3M'> 0.0010000000
# <re.Match object; span=(0, 5), match='10-4M'> 0.0001000000
# <re.Match object; span=(0, 5), match='10-3M'> 0.0010000000
#           ID                  NAME  \
# 0    10001.0  2-mercaptopyrimidine
# 1    10002.0  2-mercaptopyrimidine
# 2    10003.0  2-mercaptopyrimidine
# 3    10004.0  2-mercaptopyrimidine
# 4    10005.0  2-mercaptopyrimidine
# ..       ...                   ...
# 893  10911.0   Monoethylene glycol
# 894  10912.0   Monoethylene glycol
# 895  10913.0         Thiourea (TU)
# 896  10914.0         berberine（BB）
# 897  10915.0         berberine（BB）
#
#                                                 SMILES  NaClg/L  Temp  \
# 0                                        S=c1nccc[nH]1     10.0  313K
# 1                                        S=c1nccc[nH]1     50.0  313K
# 2                                        S=c1nccc[nH]1    100.0  313K
# 3                                        S=c1nccc[nH]1    150.0  313K
# 4                                        S=c1nccc[nH]1    200.0  313K
# ..                                                 ...      ...   ...
# 893  C=C(c1ccccc1)C5(c2ccccc2)/C(c3ccccc3)=C(c4cccc...    100.0  323K
# 894  C=C(c1ccccc1)C5(c2ccccc2)/C(c3ccccc3)=C(c4cccc...    100.0  323K
# 895                                            NC(N)=S     30.0  333K
# 896                COc5ccc4CC3c2cc1OCOc1cc2CCN3Cc4c5OC     30.0  333K
# 897                COc5ccc4CC3c2cc1OCOc1cc2CCN3Cc4c5OC     30.0  333K
#
#     Concentration      IE TempK Fixed_Concentration
# 0           20PPM  0.9124   313               20PPM
# 1           20PPM  0.8556   313               20PPM
# 2           20PPM  0.8331   313               20PPM
# 3           20PPM  0.8173   313               20PPM
# 4           20PPM  0.7629   313               20PPM
# ..            ...     ...   ...                 ...
# 893         70wt%  0.5630   323               70wt%
# 894         90wt%  0.8200   323               90wt%
# 895        10mg/L  0.7980   333              10mg/L
# 896        10mg/L  0.0180   333              10mg/L
# 897        50mg/L  0.0720   333              50mg/L
#
# [898 rows x 9 columns]

# %%
# 定义一个函数来转换浓度为g/L
def convert_concentration(row):
    try:
        mol = Chem.MolFromSmiles(row['SMILES'])
        molar_mass = Descriptors.MolWt(mol) 
    except:
        molar_mass = 1
    concentration_str = row['Fixed_Concentration']
    # 使用正则表达式匹配数字和单位
    match = re.match(r"([0-9.]+)\s*([a-zA-Z/%]+)", concentration_str)
    if not match:
        raise ValueError(f"无法解析浓度: {concentration_str},row is {row['ID']}")
    
    value, unit = match.groups()
    value = float(value)

    # 根据单位转换为M
    conversion_factors = {
        'PPM': lambda x: x / 1000, # 假设1 PPM = 1 mg/L = 0.001 g/L
        'mM': lambda x: x / 1000 * molar_mass,
        'M': lambda x: x * molar_mass,
        'muM': lambda x: x / 1000000 * molar_mass,
        'g/L': lambda x: x,
        'mg/L': lambda x: x / 1000,
        'wt%': lambda x: x * 10,
        'mL/L': lambda x: x / 1000
    }

    try:
        factor = conversion_factors[unit]
    except KeyError:
        raise ValueError(f"未知单位: {unit},row is {row['ID']}")

    return factor(value)

# %%
# 假设'Concentration'列包含浓度字符串
df['Concentrationg/L'] = df.apply(convert_concentration, axis=1)

df.head(898)
# Out:
#           ID                  NAME  \
# 0    10001.0  2-mercaptopyrimidine
# 1    10002.0  2-mercaptopyrimidine
# 2    10003.0  2-mercaptopyrimidine
# 3    10004.0  2-mercaptopyrimidine
# 4    10005.0  2-mercaptopyrimidine
# ..       ...                   ...
# 893  10911.0   Monoethylene glycol
# 894  10912.0   Monoethylene glycol
# 895  10913.0         Thiourea (TU)
# 896  10914.0         berberine（BB）
# 897  10915.0         berberine（BB）
#
#                                                 SMILES  NaClg/L  Temp  \
# 0                                        S=c1nccc[nH]1     10.0  313K
# 1                                        S=c1nccc[nH]1     50.0  313K
# 2                                        S=c1nccc[nH]1    100.0  313K
# 3                                        S=c1nccc[nH]1    150.0  313K
# 4                                        S=c1nccc[nH]1    200.0  313K
# ..                                                 ...      ...   ...
# 893  C=C(c1ccccc1)C5(c2ccccc2)/C(c3ccccc3)=C(c4cccc...    100.0  323K
# 894  C=C(c1ccccc1)C5(c2ccccc2)/C(c3ccccc3)=C(c4cccc...    100.0  323K
# 895                                            NC(N)=S     30.0  333K
# 896                COc5ccc4CC3c2cc1OCOc1cc2CCN3Cc4c5OC     30.0  333K
# 897                COc5ccc4CC3c2cc1OCOc1cc2CCN3Cc4c5OC     30.0  333K
#
#     Concentration      IE TempK Fixed_Concentration  Concentrationg/L
# 0           20PPM  0.9124   313               20PPM              0.02
# 1           20PPM  0.8556   313               20PPM              0.02
# 2           20PPM  0.8331   313               20PPM              0.02
# 3           20PPM  0.8173   313               20PPM              0.02
# 4           20PPM  0.7629   313               20PPM              0.02
# ..            ...     ...   ...                 ...               ...
# 893         70wt%  0.5630   323               70wt%            700.00
# 894         90wt%  0.8200   323               90wt%            900.00
# 895        10mg/L  0.7980   333              10mg/L              0.01
# 896        10mg/L  0.0180   333              10mg/L              0.01
# 897        50mg/L  0.0720   333              50mg/L              0.05
#
# [898 rows x 10 columns]

# %%
# 保存修改后的DataFrame到新的CSV文件
if 'Fixed_Concentration' in df.columns:
    df = df.drop('Fixed_Concentration', axis=1)
    df = df.drop('Concentration', axis=1)
    df = df.drop('Temp', axis=1)
    df = df.drop('NAME', axis=1)
df.to_csv('solution_properties_converted.csv', index=False, encoding='utf-8')

print("浓度转换完成并已保存到新的CSV文件中。")
# Out:
# 浓度转换完成并已保存到新的CSV文件中。

# %%
df2 = df.drop('NaClg/L', axis=1).drop('Concentrationg/L', axis=1).drop('TempK', axis=1)
df3 = df.drop('SMILES', axis=1).drop('IE', axis=1)
df3.to_csv('extra_data.csv', index=False, encoding='utf-8')
df2.to_csv('molecules.csv', index=False, encoding='utf-8')
